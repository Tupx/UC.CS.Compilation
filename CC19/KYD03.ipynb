# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
prodCat = pd.read_csv('product_categories.csv')

# items = ["Beverages","Condiments","Confections","Dairy Products","Grains/Cereals","Meat/Poultry","Produce","Seafood"]
# dataXD = []

# for i in items:
#   x = prodCat[prodCat['CategoryName'] == i]['Quantity']
#   dataXD.append(x)

# Seaborn
sns.set(rc={'figure.figsize':(15,9)}, font_scale=1.2, style="whitegrid")
sns.boxplot(x="CategoryName", y="Quantity", data=prodCat)

# fig1, ax1 = plt.subplots()
# ax1.boxplot(dataXD)
