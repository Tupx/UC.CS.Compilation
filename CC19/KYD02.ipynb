# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

pokemonsDf = pd.read_csv('Pokemon.csv')

# ((pokemonsDf['Type 1'] == "Normal") & (pokemonsDf['Type 2'] == "Fighting")) | ((pokemonsDf['Type 1'] == "Normal") & (pokemonsDf['Type 2'] == "Fighting"))  
xd = pokemonsDf[((pokemonsDf['Type 1'] == "Normal") | (pokemonsDf['Type 2'] == "Normal")) | ((pokemonsDf['Type 1'] == "Fighting") | (pokemonsDf['Type 2'] == "Fighting"))]
xd
# Out:
#        #                 Name    Type 1  ... Speed  Generation  Legendary
# 20    16               Pidgey    Normal  ...    56           1      False
# 21    17            Pidgeotto    Normal  ...    71           1      False
# 22    18              Pidgeot    Normal  ...   101           1      False
# 23    18  PidgeotMega Pidgeot    Normal  ...   121           1      False
# 24    19              Rattata    Normal  ...    72           1      False
# ..   ...                  ...       ...  ...   ...         ...        ...
# 743  675              Pangoro  Fighting  ...    58           6      False
# 744  676              Furfrou    Normal  ...   102           6      False
# 764  694           Helioptile  Electric  ...    70           6      False
# 765  695            Heliolisk  Electric  ...   109           6      False
# 771  701             Hawlucha  Fighting  ...   118           6      False
#
# [153 rows x 13 columns]

# %%
fig2 = plt.figure()
axes2 = fig2.add_axes([0.1,0.1,0.9,0.9])
axes2.set_title('Defense')
axes2.hist(xd['Defense'], bins='auto', alpha=0.9, rwidth=0.8)
# Out:
# (array([ 4.,  2., 12., 19., 19., 31., 26., 14., 15.,  4.,  3.,  4.]),
#  array([  5.        ,  15.33333333,  25.66666667,  36.        ,
#          46.33333333,  56.66666667,  67.        ,  77.33333333,
#          87.66666667,  98.        , 108.33333333, 118.66666667,
#         129.        ]),
#  <a list of 12 Patch objects>)
